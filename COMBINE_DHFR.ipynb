# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import utils_COMBINE as uc
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Plot made for the MSA taken from Thompson et al. 2020 (https://doi.org/10.7554/eLife.53476)
MSA = np.load('Data/MSAs/MSA_DHFRThompson.npy')

# %% [markdown]
# # Some statistics

# %%
# Amino acids distribution at site 121
uc.Stats_Pos_bis(MSA,'121',maxp=8)

# %%
# Amino acids distribution at site 13
uc.Stats_Pos_bis(MSA,'13',maxp=8)

# %%
# Amino acids at site 13 when V121
uc.Stats_Pos_bis(MSA,'13',ref_pos=('V','121'),maxp=8,perc=False)

# %% [markdown]
# # Compensatory mutation predictions

# %%
# Compensate mutation G121V in E. coli DHFR

file = 'DHFRThompson_ModelSBM_N_chains1000_N_iter400_Param_initZero_k_MCMC100000_lambda_J0.01_lambda_h0.01_m20_theta0.2_N_Av1_R0'
path = 'Data/Models/'
Nb_mut = 1
CompMut = uc.Propose_Mutation_DDE2(file,path,Nb_mut,[('V','121')],MSA_name='Thompson')
# Out:
# Mutation 2: V13G -1.7362847077833061 5.319669001765636 7.055953709548942
